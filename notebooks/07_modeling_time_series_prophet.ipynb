# %% [markdown]
# # Modeling using Time Series
#
# ---

# %% [markdown]
# ### Import Libraries

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
import fbprophet
print(fbprophet.__version__)
# import necessary packages
import pandas as pd
from fbprophet import Prophet
#from holidays import WEEKEND, HolidayBase, easter, rd
# Out:
# 0.6

# %%
from tools.tools import read_json, get_current_time

# %%
plt.style.use('ggplot')

# %%
config = read_json('../config.json')

current_date = get_current_time('yyyymmdd')

wd = f"{config['workspace_directory']}/data"

# %%
df = pd.read_csv(f"{wd}/processing/basin_int_viirs_for_modeling.csv")

# %%
df = df[df['region'] == 'Permian Region']

# %%
df['year_month'] = pd.to_datetime(df['year_month']).dt.to_period('M')
df.set_index('year_month', inplace=True)
df.sort_index(inplace=True)  # sort by datetime just to be safe

# %%
df.shape
# Out:
# (97, 83)

# %%
df
# Out:
#                     region latest_day_in_month  obs_day_cnt_avg  \
# year_month
# 2012-03     Permian Region          2012-03-31        50.964286
# 2012-04     Permian Region          2012-04-30        54.833333
# 2012-05     Permian Region          2012-05-31        80.689655
# 2012-06     Permian Region          2012-06-30        94.758621
# 2012-07     Permian Region          2012-07-31        65.225806
# ...                    ...                 ...              ...
# 2019-11     Permian Region          2019-11-30       331.607143
# 2019-12     Permian Region          2019-12-31       324.548387
# 2020-01     Permian Region          2020-01-31       309.413793
# 2020-02     Permian Region          2020-02-29       309.333333
# 2020-03     Permian Region          2020-03-08       192.571429
#
#             obs_day_cnt_med  obs_day_cnt_sum  obs_day_cnt_min  \
# year_month
# 2012-03                48.0             1427               12
# ...

# %%
X = df.drop(columns=[
    'oil_bbl_d_total_production',
    'latest_day_in_month',
    'last_day_of_month',
    'first_day_of_month',
    # 'year_month',
])

X = pd.get_dummies(X)

y = df['oil_bbl_d_total_production']

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.10, 
    shuffle=False,
)

# %%
X_train.tail(5)
# Out:
#             obs_day_cnt_avg  obs_day_cnt_med  obs_day_cnt_sum  \
# year_month
# 2019-01          304.903226            314.0             9452
# 2019-02          286.107143            299.5             8011
# 2019-03          290.933333            315.5             8728
# 2019-04          328.200000            360.0             9846
# 2019-05          303.354839            321.0             9404
#
#             obs_day_cnt_min  obs_day_cnt_max  qf_fit_day_avg_avg  \
# year_month
# 2019-01                   1              692            3.925450
# 2019-02                   3              662            3.684799
# 2019-03                   3              561            4.126076
# 2019-04                  10              651            4.746977
# 2019-05                  58              556            3.787968
#
#             qf_fit_day_avg_med  qf_fit_day_avg_sum  qf_fit_day_avg_min  \
# year_month
# 2019-01               3.710145          121.688945            0.000000
# ...

# %%
 X_test.tail(11)
# Out:
#             obs_day_cnt_avg  obs_day_cnt_med  obs_day_cnt_sum  \
# year_month
# 2019-06          336.833333            359.5            10105
# 2019-07          372.129032            365.0            11536
# 2019-08          396.548387            407.0            12293
# 2019-09          341.310345            332.0             9898
# 2019-10          327.566667            329.0             9827
# 2019-11          331.607143            326.5             9285
# 2019-12          324.548387            346.0            10061
# 2020-01          309.413793            322.0             8973
# 2020-02          309.333333            341.0             8352
# 2020-03          192.571429            288.0             1348
#
#             obs_day_cnt_min  obs_day_cnt_max  qf_fit_day_avg_avg  \
# year_month
# 2019-06                  11              636            4.222918
# 2019-07                  95              767            4.003925
# ...

# %%
for i in X_test.columns:
    print(i)
# Out:
# obs_day_cnt_avg
# obs_day_cnt_med
# obs_day_cnt_sum
# obs_day_cnt_min
# obs_day_cnt_max
# qf_fit_day_avg_avg
# qf_fit_day_avg_med
# qf_fit_day_avg_sum
# qf_fit_day_avg_min
# qf_fit_day_avg_max
# qf_fit_day_med_avg
# qf_fit_day_med_med
# qf_fit_day_med_sum
# qf_fit_day_med_min
# qf_fit_day_med_max
# qf_fit_day_sum_avg
# qf_fit_day_sum_med
# qf_fit_day_sum_sum
# qf_fit_day_sum_min
# qf_fit_day_sum_max
# qf_fit_day_min_avg
# qf_fit_day_min_med
# qf_fit_day_min_sum
# qf_fit_day_min_min
# qf_fit_day_min_max
# qf_fit_day_max_avg
# qf_fit_day_max_med
# qf_fit_day_max_sum
# qf_fit_day_max_min
# qf_fit_day_max_max
# aland
# obs_day_cnt_avg_per_squaremeters
# obs_day_cnt_med_per_squaremeters
# obs_day_cnt_sum_per_squaremeters
# obs_day_cnt_min_per_squaremeters
# obs_day_cnt_max_per_squaremeters
# qf_fit_day_avg_avg_per_squaremeters
# qf_fit_day_avg_med_per_squaremeters
# qf_fit_day_avg_sum_per_squaremeters
# qf_fit_day_avg_min_per_squaremeters
# qf_fit_day_avg_max_per_squaremeters
# ...

# %%
df_prophet = df.reset_index()[[
    'year_month', 
    'oil_bbl_d_total_production', 
    'obs_day_cnt_sum_over_pct_month_completed',
    'obs_day_cnt_avg',
]]

df_prophet['year_month'] = df_prophet['year_month'].dt.to_timestamp()
df_prophet.columns = ['ds', 'y', 'obs_day_cnt_sum_over_pct_month_completed', 'obs_day_cnt_avg']
df_prophet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a988178875bb> in <module>
# ----> 1 df_prophet = df.reset_index()[[
#       2     'year_month',
#       3     'oil_bbl_d_total_production',
#       4     'obs_day_cnt_sum_over_pct_month_completed',
#       5     'obs_day_cnt_avg',
#
# NameError: name 'df' is not defined

# %%
# Prophet follows sklearn's API so the steps are the same
manning_model = Prophet() # instantiate a new Prophet model
manning_model.fit(df_prophet); # fit the model to the data
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /Users/danielmsheehan/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/pystan/misc.py:399: FutureWarning:
#
# Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.

# %%
# Make a dataframe to hold your future predictions
manning_future = manning_model.make_future_dataframe(periods=24, freq='MS') # make a df for the future
manning_future.head(12)
# Out:
#            ds
# 0  2012-03-01
# 1  2012-04-01
# 2  2012-05-01
# 3  2012-06-01
# 4  2012-07-01
# 5  2012-08-01
# 6  2012-09-01
# 7  2012-10-01
# 8  2012-11-01
# 9  2012-12-01
# 10 2013-01-01
# 11 2013-02-01

# %%
# Use your model to 'populate' the future df with predictions
manning_forecast = manning_model.predict(manning_future)
manning_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#           ds          yhat    yhat_lower    yhat_upper
# 0 2012-03-01  1.122781e+06  1.085686e+06  1.162317e+06
# 1 2012-04-01  1.151767e+06  1.116958e+06  1.189517e+06
# 2 2012-05-01  1.163221e+06  1.126937e+06  1.201063e+06
# 3 2012-06-01  1.170608e+06  1.131615e+06  1.208987e+06
# 4 2012-07-01  1.197065e+06  1.158859e+06  1.234326e+06

# %%
prophet_preds = manning_forecast[['ds', 'yhat']].head(manning_forecast.shape[0] - 24)  # minus periods
prophet_preds
# Out:
#            ds          yhat
# 0  2012-03-01  1.122781e+06
# 1  2012-04-01  1.151767e+06
# 2  2012-05-01  1.163221e+06
# 3  2012-06-01  1.170608e+06
# 4  2012-07-01  1.197065e+06
# ..        ...           ...
# 92 2019-11-01  4.686752e+06
# 93 2019-12-01  4.707802e+06
# 94 2020-01-01  4.742288e+06
# 95 2020-02-01  4.826274e+06
# 96 2020-03-01  4.907610e+06
#
# [97 rows x 2 columns]

# %%
from sklearn.metrics import r2_score, mean_squared_error
# Calculate RMSE.
mean_squared_error(y, prophet_preds['yhat']) ** 0.5
# Out:
# 29499.589638913185

# %%
fig1 = manning_model.plot(manning_forecast)
y.plot() # 'oil_bbl_d_total_production'

# %%
fig2 = manning_model.plot_components(manning_forecast)

# %%
# example demonstrating automatic changepoints
from fbprophet.plot import add_changepoints_to_plot
fig = manning_model.plot(manning_forecast)
a = add_changepoints_to_plot(fig.gca(), manning_model, manning_forecast)

# %%
# Calculate RMSE.
mean_squared_error(y_test, preds) ** 0.5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-74dd6bff5142> in <module>
#       1 # Calculate RMSE.
# ----> 2 mean_squared_error(y_test, preds) ** 0.5
#
# NameError: name 'mean_squared_error' is not defined

# %%
manning_forecast # ['yhat']
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2012-03-01  1.129464e+06  1.085559e+06  1.163130e+06  1.129464e+06
# 1   2012-04-01  1.144134e+06  1.113384e+06  1.187524e+06  1.144134e+06
# 2   2012-05-01  1.158331e+06  1.126027e+06  1.200632e+06  1.158331e+06
# 3   2012-06-01  1.173001e+06  1.131977e+06  1.207541e+06  1.173001e+06
# 4   2012-07-01  1.187198e+06  1.159529e+06  1.231901e+06  1.187198e+06
# ..         ...           ...           ...           ...           ...
# 116 2021-11-01  6.288222e+06  6.063776e+06  6.567643e+06  6.041905e+06
# 117 2021-12-01  6.355792e+06  6.091653e+06  6.620753e+06  6.088821e+06
# 118 2022-01-01  6.425615e+06  6.103637e+06  6.684621e+06  6.137981e+06
# 119 2022-02-01  6.495438e+06  6.191332e+06  6.810592e+06  6.190288e+06
# 120 2022-03-01  6.558503e+06  6.246249e+06  6.893397e+06  6.233394e+06
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
# Evaluate predictions.
#print(mean_squared_error(y_test, preds))

# Plot data.
plt.figure(figsize=(10,6))
#plt.plot(y_train, color = 'blue')

# plt.plot(y_test, color = 'orange')
# plt.plot(preds, color = 'green')
# plt.title(label = 'Bus Ridership Monthly Volume with SARIMAX(0, 2, 1) x (0, 0, 1, 12) Predictions', fontsize=16)
# plt.show();

# %%
plt.figure(figsize=(10,6))

y.plot()
preds.plot()
y_test.plot()

# %%
plt.figure(figsize=(10,6))

preds.plot()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-08f83b8eb52e> in <module>
#       1 total_preds = model.predict(start=datetime(2012, 3, 1),
#       2                       end=datetime(2020, 3, 1),
# ----> 3                       exog=X)
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/statsmodels/base/wrapper.py in wrapper(self, *args, **kwargs)
#      93             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#      94         elif how:
# ---> 95             obj = data.wrap_output(func(results, *args, **kwargs), how)
#      96         return obj
#      97
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/statsmodels/tsa/statespace/mlemodel.py in predict(self, start, end, dynamic, **kwargs)
#    2455         """
#    2456         # Perform the prediction
# ...
