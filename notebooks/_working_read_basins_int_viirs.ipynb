# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1">Imports</a></span></li><li><span><a href="#Nightfire-2.1c" data-toc-modified-id="Nightfire-2.1c-2">Nightfire 2.1c</a></span></li><li><span><a href="#Nightfire-3.0" data-toc-modified-id="Nightfire-3.0-3">Nightfire 3.0</a></span></li><li><span><a href="#Both" data-toc-modified-id="Both-4">Both</a></span></li></ul></div>

# %% [markdown]
# # Imports

# %%
import pandas as pd
import missingno as msno
import seaborn as sns

# %%
in_21c = '/Users/danielmsheehan/Desktop/basins_int_viirs_21c_and_30/basins_int_viirs_21c.csv'
in_30 = '/Users/danielmsheehan/Desktop/basins_int_viirs_21c_and_30/basins_int_viirs_30.csv'

df_21c = pd.read_csv(in_21c)
df_30 = pd.read_csv(in_30)

# %% [markdown]
# # Nightfire 2.1c

# %%
df_21c.shape
# Out:
# (1009001, 129)

# %%
df_21c.head(3)
# Out:
#         aland  area_bb  area_pixel     awater  cbsafp  \
# 0  4727469721      NaN         NaN  301107657     NaN
# 1  4727469721      NaN         NaN  301107657     NaN
# 2  4727469721      NaN         NaN  301107657     NaN
#
#                                               ch_m12  \
# 0  0.000000;0.062081;0.086345;0.112419;0.157635;0...
# 1  0.000000;0.062081;0.086345;0.112419;0.157635;0...
# 2  0.000000;0.062081;0.086345;0.112419;0.157635;0...
#
#                                               ch_m13 classfp  cloud_mask  \
# 0  0.000000;0.074897;0.106120;0.150975;0.234767;0...      H1         0.0
# 1  0.000000;0.074897;0.106120;0.150975;0.234767;0...      H1         0.0
# 2  0.000000;0.074897;0.106120;0.150975;0.234767;0...      H1         0.0
#
#    co2_eq  ...  thr_m16  tran_dnb  tran_m07  tran_m08 tran_m10 tran_m12  \
# 0     NaN  ...  6.84127         1         1         1        1        1
# 1     NaN  ...  6.84127         1         1         1        1        1
# ...

# %%
for i in df_21c.columns:
    print(i)
# Out:
# aland
# area_bb
# area_pixel
# awater
# cbsafp
# ch_m12
# ch_m13
# classfp
# cloud_mask
# co2_eq
# cot_ivcop
# countyfp
# countyns
# csafp
# date_mscan
# date_proc
# dist_dnb
# dn_m10
# eps_ivcop
# esf_bb
# file_ac
# file_dnb
# file_gdnbo
# file_geo_dnb
# file_gmtco
# file_iicmo
# file_ivcop
# file_m07
# file_m08
# file_m10
# file_m12
# file_m13
# file_m14
# file_m15
# file_m16
# funcstat
# geoid
# geometry
# id
# id_key
# index_right
# intptlat
# intptlon
# lat_dnb
# lat_gmtco
# lat_gring
# line_bt
# line_dnb
# line_m10
# lon_dnb
# lon_gmtco
# lon_gring
# lsad
# metdivfp
# methane_eq
# mtfcc
# name
# namelsad
# pthm_m12
# pthm_m13
# pthm_m14
# pthm_m15
# pthm_m16
# qf1_dnb
# qf1_gmtco
# qf1_iicmo
# qf1_ivcop
# qf1_m07
# qf1_m08
# qf1_m10
# qf1_m12
# qf1_m13
# qf1_m14
# qf1_m15
# qf1_m16
# qf2_gmtco
# qf2_iicmo
# qf2_ivcop
# qf3_iicmo
# qf3_ivcop
# qf4_iicmo
# qf5_iicmo
# qf6_iicmo
# qf_detect
# qf_fit
# rad_dnb
# rad_m07
# rad_m08
# rad_m10
# rad_m12
# rad_m13
# rad_m14
# rad_m15
# ...

# %%
df_21c.describe()
# Out:
#               aland        area_bb     area_pixel        awater  \
# count  1.009001e+06  341426.000000  341426.000000  1.009001e+06
# mean   5.397703e+09       9.485829       0.984208  1.040855e+08
# std    2.936182e+09     138.481801       0.441829  1.119334e+08
# min    2.139571e+08       0.057951       0.575792  3.432900e+04
# 25%    2.952066e+09       1.061603       0.685169  1.410900e+07
# 50%    5.201889e+09       2.327580       0.848859  4.398582e+07
# 75%    7.149551e+09       4.937282       1.116655  1.905758e+08
# max    2.045522e+10   43470.000000       2.752860  1.139487e+09
#
#               cbsafp     cloud_mask  co2_eq     cot_ivcop      countyfp  \
# count  346878.000000  999764.000000     0.0  1.002957e+06  1.009001e+06
# mean    32313.197349       0.362002     NaN -7.369081e+02  1.464627e+02
# std     12496.896458       0.972280     NaN  4.413321e+02  1.377708e+02
# min     10420.000000       0.000000     NaN -9.999000e+02  1.000000e+00
# ...

# %%
msno.matrix(df_21c);

# %%
msno.heatmap(df_21c);

# %% [markdown]
# # Nightfire 3.0

# %%
df_30.head(3)
# Out:
#         aland  area_bb  area_pixel     awater   cbsafp classfp  cloud_mask  \
# 0  5381129960      NaN         NaN  182522236  48780.0      H1         3.0
# 1  5381129960   1.1615    0.811394  182522236  48780.0      H1         3.0
# 2  5381129960      NaN         NaN  182522236  48780.0      H1         3.0
#
#    co2_eq  countyfp  countyns  ...  qf_fit         region        rh       rhi  \
# 0     NaN       105   1035306  ...     0.0  Bakken Region       NaN       NaN
# 1     NaN       105   1035306  ...     1.0  Bakken Region  0.792865  0.977164
# 2     NaN       105   1035306  ...     0.0  Bakken Region       NaN       NaN
#
#    sample_dnb sample_m10 source_id statefp  temp_bb temp_bkg
# 0      1523.0     1142.0       NaN      38      NaN      NaN
# 1      1522.0     1142.0       NaN      38   1863.0      NaN
# 2      1553.0     1166.0       NaN      38      NaN      NaN
#
# [3 rows x 46 columns]

# %%
df_30.shape
# Out:
# (523075, 46)

# %%
for i in df_30.columns:
    print(i)
# Out:
# aland
# area_bb
# area_pixel
# awater
# cbsafp
# classfp
# cloud_mask
# co2_eq
# countyfp
# countyns
# csafp
# date_ltz
# date_mscan
# date_proc
# esf_bb
# file_dnb
# file_m10
# funcstat
# geoid
# geometry
# id
# id_key
# index_right
# intptlat
# intptlon
# lat_gmtco
# line_dnb
# line_m10
# lon_gmtco
# lsad
# metdivfp
# methane_eq
# mtfcc
# name
# namelsad
# qf_detect
# qf_fit
# region
# rh
# rhi
# sample_dnb
# sample_m10
# source_id
# statefp
# temp_bb
# temp_bkg

# %%
df_30.describe()
# Out:
#               aland        area_bb     area_pixel        awater  \
# count  5.230750e+05  385733.000000  385733.000000  5.230750e+05
# mean   5.483041e+09       4.297029       1.019162  9.432209e+07
# std    3.072098e+09      90.593690       0.462677  1.105020e+08
# min    2.139571e+08       0.065812       0.575792  3.432900e+04
# 25%    2.369725e+09       0.551420       0.704627  8.469171e+06
# 50%    5.201889e+09       1.101350       0.879304  2.015185e+07
# 75%    7.149551e+09       2.590010       1.184180  1.905758e+08
# max    2.045522e+10   35566.000000       2.743030  1.139487e+09
#
#               cbsafp    cloud_mask  co2_eq       countyfp      countyns  \
# count  214726.000000  495932.00000     0.0  523075.000000  5.230750e+05
# mean    31725.343368       0.61237     NaN     174.544857  1.240113e+06
# std     11681.049810       1.12974     NaN     154.078905  2.324705e+05
# min     10420.000000       0.00000     NaN       1.000000  6.376100e+04
# ...

# %%
msno.matrix(df_30);

# %%
msno.heatmap(df_30);

# %%
df_30['aland'].hist()

# %%
sns.pairplot(df_30);
# Out:
# /Users/danielmsheehan/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/danielmsheehan/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /Users/danielmsheehan/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6735: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /Users/danielmsheehan/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6736: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ------------------------------------------------------------------
# ValueError                       Traceback (most recent call last)
# <ipython-input-30-8fcb123d29b1> in <module>
# ----> 1 sns.pairplot(df_30)
#
# ...

# %% [markdown]
# # Both

# %%
df_21c.columns & df_30.columns
# Out:
# Index(['aland', 'area_bb', 'area_pixel', 'awater', 'cbsafp', 'classfp',
#        'cloud_mask', 'co2_eq', 'countyfp', 'countyns', 'csafp', 'date_mscan',
#        'date_proc', 'esf_bb', 'file_dnb', 'file_m10', 'funcstat', 'geoid',
#        'geometry', 'id', 'id_key', 'index_right', 'intptlat', 'intptlon',
#        'lat_gmtco', 'line_dnb', 'line_m10', 'lon_gmtco', 'lsad', 'metdivfp',
#        'methane_eq', 'mtfcc', 'name', 'namelsad', 'qf_detect', 'qf_fit',
#        'region', 'rh', 'rhi', 'sample_dnb', 'sample_m10', 'statefp', 'temp_bb',
#        'temp_bkg'],
#       dtype='object')

# %%
import numpy as np
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from matplotlib.animation import FFMpegWriter

# Fixing random state for reproducibility
np.random.seed(19680801)


metadata = dict(title='Movie Test', artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=15, metadata=metadata)

fig = plt.figure()
l, = plt.plot([], [], 'k-o')

plt.xlim(-5, 5)
plt.ylim(-5, 5)

x0, y0 = 0, 0

with writer.saving(fig, "writer_test.mp4", 100):
    for i in range(100):
        x0 += 0.1 * np.random.randn()
        y0 += 0.1 * np.random.randn()
        l.set_data(x0, y0)
        writer.grab_frame()

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib
matplotlib.use('TkAgg')

fig, ax = plt.subplots()
fig.set_tight_layout(True)

# Query the figure's on-screen size and DPI. Note that when saving the figure to
# a file, we need to provide a DPI for that separately.
print('fig size: {0} DPI, size in inches {1}'.format(
    fig.get_dpi(), fig.get_size_inches()))

# Plot a scatter that persists (isn't redrawn) and the initial line.
x = np.arange(0, 20, 0.1)
ax.scatter(x, x + np.random.normal(0, 3.0, len(x)))
line, = ax.plot(x, x - 5, 'r-', linewidth=2)

def update(i):
    label = 'timestep {0}'.format(i)
    print(label)
    # Update the line and the axes (with a new xlabel). Return a tuple of
    # "artists" that have to be redrawn for this frame.
    line.set_ydata(x - 5 + i)
    ax.set_xlabel(label)
    return line, ax

if __name__ == '__main__':
    # FuncAnimation will call the 'update' function for each frame; here
    # animating over 10 frames, with an interval of 200ms between frames.
    anim = FuncAnimation(fig, update, frames=np.arange(0, 10), interval=200)
    if len(sys.argv) > 1 and sys.argv[1] == 'save':
        anim.save('line.gif', dpi=80, writer='imagemagick')
    else:
        # plt.show() will just loop the animation forever.
        anim.save('line.gif', dpi=80, writer='imagemagick')
        plt.show()
# Out:
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# fig size: 72.0 DPI, size in inches [6. 4.]
# timestep 0
# timestep 0
# timestep 1
# timestep 2
# timestep 3
# timestep 4
# timestep 5
# timestep 6
# timestep 7
# timestep 8
# timestep 9
